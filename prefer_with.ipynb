# %%
import pandas as pd 
data = pd.read_csv('/content/prefer.with.csv')
data.dtypes #variables in data and their datatypes
# Out:
# layerID         int64
# from            int64
# to              int64
# gender.from    object
# dtype: object

# %%
import networkx as nx
FG = nx.from_pandas_edgelist(data, source='from', target='to', edge_attr=True,)

# %%
# network diagram
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
nx.draw_networkx(FG)
plt.show()

# %%
nx.center(FG)
# Out:
# [14, 16, 21, 20, 22, 23, 24]

# %%
# finding the shortest distance between two nodes
#print("shortest path: ", nx.shortest_path(G1,0,7))
nx.shortest_path_length(FG, nx.center(FG)[0])
# Out:
# {14: 0,
#  1: 1,
#  6: 1,
#  8: 1,
#  11: 1,
#  12: 1,
#  13: 1,
#  15: 1,
#  16: 1,
#  17: 1,
#  19: 1,
#  20: 1,
#  21: 1,
#  22: 1,
#  23: 1,
#  24: 1,
#  26: 1,
#  27: 1,
#  2: 2,
#  3: 2,
#  4: 2,
#  5: 2,
#  7: 2,
#  9: 2,
#  10: 2,
#  18: 2,
#  25: 2,
#  28: 2,
#  29: 2}

# %%
for i in nx.center(FG):
#nx.shortest_path_length(FG, i)
    print(nx.shortest_path_length(FG, i))
# Out:
# {14: 0, 1: 1, 6: 1, 8: 1, 11: 1, 12: 1, 13: 1, 15: 1, 16: 1, 17: 1, 19: 1, 20: 1, 21: 1, 22: 1, 23: 1, 24: 1, 26: 1, 27: 1, 2: 2, 3: 2, 4: 2, 5: 2, 7: 2, 9: 2, 10: 2, 18: 2, 25: 2, 28: 2, 29: 2}
# {16: 0, 1: 1, 2: 1, 5: 1, 6: 1, 8: 1, 9: 1, 11: 1, 12: 1, 13: 1, 14: 1, 15: 1, 17: 1, 19: 1, 20: 1, 21: 1, 22: 1, 23: 1, 24: 1, 3: 2, 4: 2, 7: 2, 10: 2, 18: 2, 25: 2, 26: 2, 27: 2, 28: 2, 29: 2}
# {21: 0, 2: 1, 5: 1, 6: 1, 8: 1, 11: 1, 13: 1, 14: 1, 15: 1, 16: 1, 19: 1, 20: 1, 22: 1, 23: 1, 1: 2, 3: 2, 4: 2, 7: 2, 9: 2, 10: 2, 12: 2, 17: 2, 18: 2, 24: 2, 25: 2, 26: 2, 27: 2, 28: 2, 29: 2}
# {20: 0, 6: 1, 8: 1, 11: 1, 13: 1, 14: 1, 15: 1, 16: 1, 19: 1, 21: 1, 22: 1, 23: 1, 26: 1, 27: 1, 1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 7: 2, 9: 2, 10: 2, 12: 2, 17: 2, 18: 2, 24: 2, 25: 2, 28: 2, 29: 2}
# {22: 0, 6: 1, 8: 1, 11: 1, 13: 1, 14: 1, 15: 1, 16: 1, 19: 1, 20: 1, 21: 1, 23: 1, 26: 1, 27: 1, 1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 7: 2, 9: 2, 10: 2, 12: 2, 17: 2, 18: 2, 24: 2, 25: 2, 28: 2, 29: 2}
# {23: 0, 6: 1, 8: 1, 9: 1, 11: 1, 13: 1, 14: 1, 15: 1, 16: 1, 19: 1, 20: 1, 21: 1, 22: 1, 24: 1, 28: 1, 29: 1, 1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 7: 2, 10: 2, 12: 2, 17: 2, 18: 2, 25: 2, 26: 2, 27: 2}
# {24: 0, 6: 1, 8: 1, 13: 1, 14: 1, 15: 1, 16: 1, 17: 1, 19: 1, 23: 1, 26: 1, 27: 1, 28: 1, 29: 1, 1: 2, 2: 2, 3: 2, 4: 2, 5: 2, 7: 2, 9: 2, 10: 2, 11: 2, 12: 2, 18: 2, 20: 2, 21: 2, 22: 2, 25: 2}

# %%
nx.diameter(FG)
# Out:
# 4

# %%
nx.eccentricity(FG)
# Out:
# {1: 3,
#  2: 3,
#  5: 3,
#  6: 3,
#  11: 3,
#  12: 3,
#  14: 2,
#  16: 2,
#  8: 3,
#  10: 4,
#  15: 3,
#  21: 2,
#  3: 4,
#  4: 4,
#  7: 4,
#  19: 3,
#  17: 3,
#  20: 2,
#  22: 2,
#  23: 2,
#  24: 2,
#  26: 3,
#  27: 3,
#  29: 3,
#  9: 3,
#  13: 3,
#  18: 4,
#  25: 4,
#  28: 3}

# %%
nx.periphery(FG)
# Out:
# [10, 3, 4, 7, 18, 25]

# %%
density = nx.density(FG)

print('The edge density is: ' + str(density))
# Out:
# The edge density is: 0.37438423645320196

# %%
# find the number of edges.
dc=nx.degree_centrality(FG)
for i in dc:
    print("Node[",i,"]",dc[i])
# Out:
# Node[ 1 ] 0.2857142857142857
# Node[ 2 ] 0.3571428571428571
# Node[ 5 ] 0.39285714285714285
# Node[ 6 ] 0.75
# Node[ 11 ] 0.6071428571428571
# Node[ 12 ] 0.3571428571428571
# Node[ 14 ] 0.6071428571428571
# Node[ 16 ] 0.6428571428571428
# Node[ 8 ] 0.7142857142857142
# Node[ 10 ] 0.14285714285714285
# Node[ 15 ] 0.5
# Node[ 21 ] 0.46428571428571425
# Node[ 3 ] 0.25
# Node[ 4 ] 0.14285714285714285
# Node[ 7 ] 0.10714285714285714
# Node[ 19 ] 0.5
# Node[ 17 ] 0.17857142857142855
# Node[ 20 ] 0.46428571428571425
# Node[ 22 ] 0.46428571428571425
# Node[ 23 ] 0.5357142857142857
# Node[ 24 ] 0.46428571428571425
# Node[ 26 ] 0.2857142857142857
# Node[ 27 ] 0.3214285714285714
# Node[ 29 ] 0.25
# Node[ 9 ] 0.21428571428571427
# Node[ 13 ] 0.42857142857142855
# Node[ 18 ] 0.07142857142857142
# Node[ 25 ] 0.07142857142857142
# Node[ 28 ] 0.2857142857142857

# %%
# closeness Centrality
CC=nx.closeness_centrality(FG)

for i in CC:
    print("Node[",i,"]",CC[i])
# Out:
# Node[ 1 ] 0.5490196078431373
# Node[ 2 ] 0.5833333333333334
# Node[ 5 ] 0.5957446808510638
# Node[ 6 ] 0.7567567567567568
# Node[ 11 ] 0.6829268292682927
# Node[ 12 ] 0.5833333333333334
# Node[ 14 ] 0.717948717948718
# Node[ 16 ] 0.7368421052631579
# Node[ 8 ] 0.7368421052631579
# Node[ 10 ] 0.45901639344262296
# Node[ 15 ] 0.6511627906976745
# Node[ 21 ] 0.6511627906976745
# Node[ 3 ] 0.509090909090909
# Node[ 4 ] 0.4827586206896552
# Node[ 7 ] 0.4444444444444444
# Node[ 19 ] 0.6363636363636364
# Node[ 17 ] 0.5283018867924528
# Node[ 20 ] 0.6511627906976745
# Node[ 22 ] 0.6511627906976745
# Node[ 23 ] 0.6829268292682927
# Node[ 24 ] 0.6511627906976745
# Node[ 26 ] 0.5384615384615384
# Node[ 27 ] 0.5490196078431373
# Node[ 29 ] 0.5490196078431373
# Node[ 9 ] 0.5384615384615384
# Node[ 13 ] 0.5833333333333334
# Node[ 18 ] 0.3783783783783784
# Node[ 25 ] 0.3783783783783784
# Node[ 28 ] 0.5283018867924528

# %%
bc=nx.betweenness_centrality(FG,normalized=True, endpoints=False)
print(bc)
# Out:
# {1: 0.0006246325690770135, 2: 0.008914619395683164, 5: 0.012915605671801712, 6: 0.11599298457764068, 11: 0.07589973482482533, 12: 0.007547381092354636, 14: 0.050404559883117386, 16: 0.05954189933234768, 8: 0.12119292840888495, 10: 0.0, 15: 0.030995965342247703, 21: 0.018800458723182197, 3: 0.007418727656822895, 4: 0.0, 7: 0.0, 19: 0.02111639340475319, 17: 0.0, 20: 0.019814010906325022, 22: 0.019814010906325022, 23: 0.04118660754347193, 24: 0.030867189938479263, 26: 0.009639033316281992, 27: 0.005330643293606256, 29: 0.004888994505396622, 9: 0.006285410650490018, 13: 0.1442026399036981, 18: 0.0, 25: 0.0, 28: 0.006711388259007306}

# %%
bc1=nx.betweenness_centrality(FG,normalized=True, endpoints=False,k=4)
print(bc1)
# Out:
# {1: 0.0, 2: 0.0, 5: 0.0, 6: 0.1405954743008314, 11: 0.0841403691106072, 12: 0.020184555303602924, 14: 0.027357987948265727, 16: 0.04490911333669271, 8: 0.15250679747207524, 10: 0.0, 15: 0.027099211598219534, 21: 0.00913328294280675, 3: 0.0, 4: 0.0, 7: 0.0, 19: 0.01809531683043588, 17: 0.0, 20: 0.003196649029982363, 22: 0.003196649029982363, 23: 0.02722098870412362, 24: 0.003501091794742588, 26: 0.01463608591584782, 27: 0.011553602922650542, 29: 0.001750545897371294, 9: 0.012611541530192323, 13: 0.08878692680776015, 18: 0.0, 25: 0.0, 28: 0.0}

# %%
# Local Clustering Coefficient 
print(nx.clustering(FG,nx.center(FG)))
for i in FG:
    print (nx.clustering(FG,i))

# Global Clustering

print("Global clustering using Average clustering: ", nx.average_clustering(FG))
# Out:
# {14: 0.5808823529411765, 16: 0.5751633986928104, 21: 0.7692307692307693, 20: 0.717948717948718, 22: 0.717948717948718, 23: 0.638095238095238, 24: 0.5897435897435898}
# 0.9285714285714286
# 0.7555555555555555
# 0.7090909090909091
# 0.4666666666666667
# 0.47794117647058826
# 0.7555555555555555
# 0.5808823529411765
# 0.5751633986928104
# 0.43157894736842106
# 1.0
# 0.6263736263736264
# 0.7692307692307693
# 0.6190476190476191
# 1.0
# 1.0
# 0.6593406593406593
# 1.0
# 0.717948717948718
# 0.717948717948718
# 0.638095238095238
# 0.5897435897435898
# 0.5357142857142857
# 0.6944444444444444
# 0.7619047619047619
# 0.5333333333333333
# 0.48484848484848486
# 1.0
# 1.0
# 0.6428571428571429
# Global clustering using Average clustering:  0.712821978680845

# %%
#ZKC_graph = nx.karate_club_graph()

nx.draw_networkx(FG)
#Let's keep track of which nodes represent John A and Mr Hi
Mr_Hi = 0
John_A = 33

#Let's display the labels of which club each member ended up joining
club_labels = nx.get_node_attributes(FG,'club')


#just show a couple of the labels
#print({key:club_labels[key] for key in range(10,16)})

# %%
#To plot using networkx we first need to get the positions we want for each node. 
#Here we will use a ciruclar layout but there are many other variations you could choose!
circ_pos = nx.circular_layout(FG) 


#Use the networkx draw function to easily visualise the graph
nx.draw(FG,circ_pos)

col=["#eb6134","#3a34eb","#eb3440","#eb34bd","#8f34eb","#34b4eb","#34eb9b"]
#let's highlight Mr Hi (green) and John A (red)
for i in range(0,len(nx.center(FG))):
    nx.draw_networkx_nodes(FG, circ_pos, nodelist=[nx.center(FG)[i]], node_color=col[i], alpha=1)
#nx.draw_networkx_nodes(FG, circ_pos, nodelist=[John_A], node_color='r', alpha=1)

# %%
density = nx.density(FG)

print('The edge density is: ' + str(density))
# Out:
# The edge density is: 0.37438423645320196

# %%
# find the number of edges.
dc=nx.degree_centrality(FG)
print(dc)

len(dc)
# Out:
# {1: 0.2857142857142857, 2: 0.3571428571428571, 5: 0.39285714285714285, 6: 0.75, 11: 0.6071428571428571, 12: 0.3571428571428571, 14: 0.6071428571428571, 16: 0.6428571428571428, 8: 0.7142857142857142, 10: 0.14285714285714285, 15: 0.5, 21: 0.46428571428571425, 3: 0.25, 4: 0.14285714285714285, 7: 0.10714285714285714, 19: 0.5, 17: 0.17857142857142855, 20: 0.46428571428571425, 22: 0.46428571428571425, 23: 0.5357142857142857, 24: 0.46428571428571425, 26: 0.2857142857142857, 27: 0.3214285714285714, 29: 0.25, 9: 0.21428571428571427, 13: 0.42857142857142855, 18: 0.07142857142857142, 25: 0.07142857142857142, 28: 0.2857142857142857}
# 29

# %%
CC=nx.closeness_centrality(FG)
print(CC)

len(CC)
# Out:
# {1: 0.5490196078431373, 2: 0.5833333333333334, 5: 0.5957446808510638, 6: 0.7567567567567568, 11: 0.6829268292682927, 12: 0.5833333333333334, 14: 0.717948717948718, 16: 0.7368421052631579, 8: 0.7368421052631579, 10: 0.45901639344262296, 15: 0.6511627906976745, 21: 0.6511627906976745, 3: 0.509090909090909, 4: 0.4827586206896552, 7: 0.4444444444444444, 19: 0.6363636363636364, 17: 0.5283018867924528, 20: 0.6511627906976745, 22: 0.6511627906976745, 23: 0.6829268292682927, 24: 0.6511627906976745, 26: 0.5384615384615384, 27: 0.5490196078431373, 29: 0.5490196078431373, 9: 0.5384615384615384, 13: 0.5833333333333334, 18: 0.3783783783783784, 25: 0.3783783783783784, 28: 0.5283018867924528}
# 29

# %%
bc=nx.betweenness_centrality(FG,normalized=True, endpoints=False)
print(bc)

len(bc)
# Out:
# {1: 0.0006246325690770135, 2: 0.008914619395683164, 5: 0.012915605671801712, 6: 0.11599298457764068, 11: 0.07589973482482533, 12: 0.007547381092354636, 14: 0.050404559883117386, 16: 0.05954189933234768, 8: 0.12119292840888495, 10: 0.0, 15: 0.030995965342247703, 21: 0.018800458723182197, 3: 0.007418727656822895, 4: 0.0, 7: 0.0, 19: 0.02111639340475319, 17: 0.0, 20: 0.019814010906325022, 22: 0.019814010906325022, 23: 0.04118660754347193, 24: 0.030867189938479263, 26: 0.009639033316281992, 27: 0.005330643293606256, 29: 0.004888994505396622, 9: 0.006285410650490018, 13: 0.1442026399036981, 18: 0.0, 25: 0.0, 28: 0.006711388259007306}
# 29

# %%
bc2=nx.eigenvector_centrality(FG)
print(bc2)
# Out:
# {1: 0.14606277515050936, 2: 0.16474032344903164, 5: 0.18153146417084398, 6: 0.3066843091628504, 11: 0.2401553006760093, 12: 0.1693460185782458, 14: 0.27462902651657484, 16: 0.28758547428889925, 8: 0.27864974749833693, 10: 0.06638698187770829, 15: 0.2338487917641073, 21: 0.236455316226062, 3: 0.09283529206343767, 4: 0.07047321325984461, 7: 0.046938005881697165, 19: 0.23559524484831376, 17: 0.1034907034551186, 20: 0.23044598653572457, 22: 0.23044598653572457, 23: 0.24874488038467732, 24: 0.20102664251615707, 26: 0.12219643914693055, 27: 0.1397623252294923, 29: 0.10834539452538212, 9: 0.0974737683158716, 13: 0.16816512067669354, 18: 0.013977670181335972, 25: 0.013977670181335972, 28: 0.11186332035553762}
